# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center>
#   <a href="CM2015_Week3B.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="CM2015_Week3D.ipynb">Next Page</a></center>
# </center>

# %% [markdown]
# # Essential of Natural Language Processing
# ## using Natural Language Toolkit (nltk): WordCloud

# %%
import pandas as pd
import nltk
from nltk.probability import FreqDist
from wordcloud import WordCloud  # Is not installed.
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-aac7647e1c1f> in <module>
#       2 import nltk
#       3 from nltk.probability import FreqDist
# ----> 4 from wordcloud import WordCloud  # Is not installed.
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ## Word Cloud

# %%
myWords =[]

f = open('HanselNGretel.txt', 'r')
data=f.read()

#index = data.index
#number_of_rows=len(index)
#print(number_of_rows)

# %%
Mywords=nltk.word_tokenize(data)

# %%
data_analysis=nltk.FreqDist(Mywords)

# %%
data_analysis

# %%
filt_word={}
for Wrd, Cnt in data_analysis.items():
    #print(Wrd,Cnt)
    if len(Wrd) > 5:
        filt_word[Wrd]=Cnt

# %% [markdown]
# #### Generating WordCloud Object

# %%
wcloud=WordCloud().generate_from_frequencies(filt_word)

# %%
wcloud.background_color='black'

# %%
plt.imshow(wcloud, interpolation='bilinear')
#plt.axis("off")
plt.axis("on")
(-1.5, 200, 100, -2.5)
plt.show()

# %%
plt.imshow(wcloud)

# %%
plt.imshow(wcloud)
#plt.axis([-1.5, 200, 100, -2.5])
plt.axis([0, 400, 200, 0])
#plt.axis("off")
plt.show()

# %% [markdown]
# ## Exercise Individual (8 minutes)
#
# * Get the data about covid19.
# * Generate Word Cloud

# %%
myWords =[]

f = open('covid19.txt', 'r')
covid19=f.read()

#index = data.index

# %%
covidWords=nltk.word_tokenize(covid19)
data_analysis=nltk.FreqDist(covidWords)
data_analysis
# Out:
# FreqDist({'cases': 8, 'the': 8, '.': 8, ',': 7, 'were': 5, 'and': 5, 'in': 4, 'of': 4, 'are': 4, 'new': 3, ...})

# %%
wcloud=WordCloud().generate_from_frequencies(data_analysis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-defb89c42ad7> in <module>
# ----> 1 wcloud=WordCloud().generate_from_frequencies(data_analysis)
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# <center>
#   <a href="CM2015_Week3B.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="CM2015_Week3D.ipynb">Next Page</a></center>
# </center>
